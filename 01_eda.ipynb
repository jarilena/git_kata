# %%
# %reload_ext autoreload
# %autoreload 2
# Out:
# Running cells with 'git_kata (Python 3.13.0)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/Users/s/git_kata/.venv/bin/python -m pip install ipykernel -U --force-reinstall'

# %%
from utils import load_data

titanic = load_data()

titanic.head(10)
